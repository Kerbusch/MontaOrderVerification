# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline

# %%
# Load a model
model = YOLO('MontaOrderVerification/oot_model0003/weights/best.pt')  # load a custom model

# %%
folder_path = '../Datasets/Dataset_OOT_YOLOv8/Test/'
for files in os.listdir( folder_path):
    # Predict with the model
    results = model.predict(os.path.join(folder_path, files))

    res_plotted = results[0].plot()

    # Convert the image from BGR to RGB
    image = cv2.cvtColor(res_plotted, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.axis('off')
    plt.show()
# Out:
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\2_skus_zwarte_bg.png: 480x640 1 keto granola, 1 koffie keto, 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\2_sku_test.png: 640x512 1 keto granola, 1 koffie keto, 40.0ms
# Speed: 2.0ms preprocess, 40.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\2_sku_test2.png: 640x480 1 keto granola, 1 pumpkin spice, 39.0ms
# Speed: 2.0ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\640x640_test.png: 640x640 1 keto granola, 1 pumpkin spice, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\640x640_test_grijs.png: 640x640 1 keto granola, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\640x640_test_grijs2.png: 640x640 1 keto granola, 1 pumpkin spice, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\Afbeelding6.png: 640x640 (no detections), 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\Afbeelding7.png: 640x640 (no detections), 6.0ms
# Speed: 4.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\duo pak (1).png: 640x288 1 koffie keto, 38.0ms
# Speed: 1.0ms preprocess, 38.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\duo pak (2).png: 640x288 (no detections), 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\keto_granola_wit.png: 640x384 (no detections), 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\MicrosoftTeams-image (17).png: 640x288 (no detections), 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\MicrosoftTeams-image (18).png: 640x288 (no detections), 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\MicrosoftTeams-image (19).png: 640x288 1 koffie keto, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\oot-kg-3.png: 448x640 (no detections), 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\oot-kg-4.png: 352x640 (no detections), 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\test_2_sku_grijs.jpg: 480x640 (no detections), 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\Daniel.Hoegee\Documents\MontaOrderVerification\Datasets\Dataset_OOT_YOLOv8\Test\test_val.jpg: 480x640 1 keto granola, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
